# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
size = 1
n = 2**(size + 2**size)

def create_mux(x):
    size = np.int(np.log2(x.shape[1]))
    a = x[:, :2**size]
    b = x[:, -size:]
    c = np.sum([(b[:, size-i-1]>0.5) * 2**i for i in range(size)], axis=0)  # Selected

    return np.array([1/a[i, 2**size-int(c[i])-1] for i in range(a.shape[0])])

# x = np.random.randint(0, 2, size=(n, 2**size+size))  # Random bits
# x = np.array([[int(j) for j in np.binary_repr(i, width=size + 2**size)] for i in range(n-1)])  # First seven

#x = np.concatenate((np.random.rand(200, 2), np.random.randint(0, 2, size=(200, 1))), axis=1)
x = (np.random.rand(200, 3)+0.2)/1.2
print(x)
y = create_mux(x)
np.save("simple.npy", np.concatenate((x,y.reshape(-1,1)), axis=1))
# Out:
# [[0.69477271 0.49181305 0.96398409]
#  [0.57656075 0.84990248 0.65530682]
#  [0.87534912 0.31521236 0.67402472]
#  [0.16801936 0.23616121 0.93054787]
#  [0.90353534 0.82834145 0.40533678]
#  [0.44492508 0.62653554 0.52427902]
#  [0.34452667 0.28803516 0.70296612]
#  [0.40036286 0.18807546 0.90899197]
#  [0.66818127 0.60484768 0.85479349]
#  [0.78320383 0.31522469 0.57069628]
#  [0.44966359 0.93985455 0.83503698]
#  [0.42933309 0.3317317  0.62624431]
#  [0.35257091 0.50752511 0.94234952]
#  [0.23830695 0.26038828 0.47622633]
#  [0.40965211 0.59414359 0.46779946]
#  [0.91182922 0.91672565 0.52602391]
#  [0.74847986 0.98371224 0.6476283 ]
#  [0.48419767 0.95304012 0.34148835]
#  [0.33297032 0.61614621 0.9919197 ]
#  [0.62744239 0.6544227  0.71559967]
#  [0.96961737 0.66802618 0.26607781]
#  [0.35587904 0.21230792 0.52074687]
#  [0.20776176 0.80472591 0.86660478]
#  [0.71999391 0.24462129 0.9269351 ]
#  [0.95454141 0.57198719 0.87083305]
#  [0.86724103 0.78738558 0.96390928]
#  [0.9723783  0.17826727 0.45961379]
#  [0.35990947 0.98229886 0.46661503]
#  [0.94617727 0.34907742 0.19421794]
#  [0.74839201 0.78169891 0.8598023 ]
#  [0.85446907 0.56193026 0.18858544]
#  [0.2917384  0.20189538 0.17712409]
#  [0.25278646 0.7609401  0.17968272]
#  [0.77381899 0.60521853 0.9197933 ]
#  [0.54101926 0.44552338 0.87463455]
#  [0.43406128 0.21994625 0.44624345]
#  [0.84140266 0.38447053 0.94844909]
#  [0.39170701 0.81710457 0.4466585 ]
#  [0.9468514  0.43789887 0.89821875]
#  [0.91860092 0.83632151 0.50788476]
#  [0.9872483  0.42226692 0.6077896 ]
#  [0.73353445 0.37442235 0.52316328]
#  [0.1993911  0.48331785 0.34307645]
#  [0.5254841  0.70573637 0.46412684]
#  [0.99527773 0.26746439 0.16768121]
#  [0.72297578 0.90432437 0.98606391]
#  [0.28457468 0.77516421 0.66376804]
#  [0.78144845 0.48801952 0.74923231]
#  [0.41023022 0.20189803 0.73638254]
#  [0.94843451 0.83734078 0.23837363]
#  [0.53422471 0.35243629 0.96015007]
#  [0.30426289 0.60347283 0.52318564]
#  [0.99310039 0.4862529  0.27874649]
#  [0.62867467 0.38668529 0.688691  ]
#  [0.82372475 0.48702103 0.98031399]
#  [0.77194938 0.53642338 0.3106296 ]
#  [0.79748774 0.47004232 0.59835556]
#  [0.57062164 0.65199001 0.70531579]
#  [0.29968006 0.83120724 0.78164895]
#  [0.68857446 0.52811517 0.7546042 ]
#  [0.21802657 0.59095673 0.76679386]
#  [0.57871275 0.99640624 0.56508562]
#  [0.42717231 0.33767693 0.2521869 ]
#  [0.67543882 0.48788733 0.83684267]
#  [0.80989426 0.61102318 0.9867814 ]
#  [0.98707391 0.7755899  0.71298337]
#  [0.65840539 0.21276916 0.56818173]
#  [0.31420368 0.76009039 0.66241905]
#  [0.74513056 0.54195859 0.31030745]
#  [0.79716307 0.41145068 0.32282581]
#  [0.50281081 0.27136814 0.38133525]
#  [0.38755725 0.94598689 0.77031065]]

# %%
fig = plt.figure(1)
ax = Axes3D(fig, elev=48, azim=134)

#ax.scatter(x[y==0, 0], x[y==0, 1], x[y==0, 2], label="Class 0")
#ax.scatter(x[y==1, 0], x[y==1, 1], x[y==1, 2], label="Class 1")
x_aux = x[x[:, 2]<0.5]
y_aux = y[x[:, 2]<0.5]

ax.scatter(x_aux[:, 0], x_aux[:, 1], x_aux[:, 2])
x_aux = x[x[:, 2]>0.5]
y_aux = y[x[:, 2]>0.5]

ax.scatter(x_aux[:, 0], x_aux[:, 1], x_aux[:, 2])
ax.set_xlabel('x1')
ax.set_ylabel('x2')
ax.set_zlabel('x3')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
sigma = 0.1

# %%
c0 = np.random.normal([0, 1, 2], sigma, size=[20, 3])
c1 = np.random.normal([1, 1, 2], sigma, size=[20, 3])
c2 = np.random.normal([0, 2, 2], sigma, size=[20, 3])
c3 = np.random.normal([0, 1, 3], sigma, size=[20, 3])
X = np.concatenate([c0, c1, c2, c3])
y = np.array([[0]]*20+[[1]]*20+[[2]]*20+[[3]]*20)
data = np.concatenate([X,y], axis=1)
np.save("SyntheticData2.npy", data)

# %%
c0 = np.random.normal([0, 1, 2, 3], sigma, size=[20, 4])
c1 = np.random.normal([0, 1, 2, 4], sigma, size=[20, 4])
c2 = np.random.normal([1, 1, 2, 3], sigma, size=[20, 4])
c3 = np.random.normal([0, 2, 2, 3], sigma, size=[20, 4])
c4 = np.random.normal([0, 1, 3, 3], sigma, size=[20, 4])
X = np.concatenate([c0, c1, c2, c3, c4])
y = np.array([[0]]*20+[[1]]*20+[[2]]*20+[[3]]*20+[[4]]*20)
data = np.concatenate([X,y], axis=1)
np.save("SyntheticData3.npy", data)
